# %% [markdown]
# <a href="https://colab.research.google.com/github/PRATIK17492/AgriSmart-Adviser/blob/main/courses/udacity_intro_to_tensorflow_for_deep_learning/l01c01_introduction_to_colab_and_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("====================================")
print("     pratik eletricity saver")
print("====================================")

eletricity_units = int(input("enter your units: "))
units = float(input("enter the price of 1 unit:"))

total_bil = eletricity_units*units

print("\n============ Electricity Report ============")
print(f"Total Units Used: {eletricity_units}")
print(f"Total Bill: rs{total_bil}")

if total_bil <= 700:
 print(f"total bill = {total_bil} ")
 print("usage level = low good job")
 print("tip: continue this process weldone")
else:
  print(f"total bill = {total_bil}")
  print("usage level = high very bad")
  print("tip: switch of the lights and fans when it is not in use")
# Out:
# ...
#      pratik eletricity saver
# ...
# enter your units: 234
# enter the price of 1 unit:3
#
# ============ Electricity Report ============
# Total Units Used: 234
# Total Bill: rs702.0
# total bill = 702.0
# usage level = high very bad
# tip: switch of the lights and fans when it is not in use
